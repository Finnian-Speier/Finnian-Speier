# %%
def total(List):
    total = 0
    n = len(List)
    for i in range(n):
        total += List[i]
    return total
#this is a list i made to test some of the funtions 
job=[1,2,3,4,5,6,7,8,1,1,2,6,8,25,32]

print(total(job))

def mean(List):
    mean_ = total(List) / len(List)
    return mean_

print(mean(job))

def median(List):
    n = len(List)
    List = sorted(List)
    #figurues out if its odd or even, since taking the median is diffrent for even lists since there is no true middle
    if n % 2 != 0:
        middle_index = int((n - 1) / 2)
        median_ = List[middle_index]
    else:
        upper_middle_index = int(n / 2)
        lower_middle_index = (upper_middle_index - 1)
        median_ = mean(List[lower_middle_index : upper_middle_index + 1])
        
    return median_
print(median(job))
def mode(List):
    max_count = 0
    counter_dict = {}
    for value in List:
        counter_dict[value] = 0
    for value in List:
        #just adds one to that vales count for each instance of it in the list
        counter_dict[value] += 1
    count_list = list(counter_dict.values())
    #this line figures out witch of the numbers has the highest counts 
    max_count = max(count_list)
    mode_ = [key for key in counter_dict if counter_dict[key] == max_count]
    
    return mode_
print(mode(job))
def variance(List, sample = False):
    #for this funtion there needs to be two arguments one for the list and the other for weather its a sample or not
    #calles the mean funtion
    list_mean = mean(List)
    n = len(List)
    sum_sq_diff = 0
    for val in List:
        #this line takes all values in the list and subtracts them from the mean and squares the result
        sum_sq_diff += (val - list_mean) ** 2
    if sample == False:
        variance_ = sum_sq_diff / n
    else:
        variance_ = sum_sq_diff / (n - 1)
    
    return variance_
print()
def SD(List, sample = False):
    #for this funtion there needs to be two arguments one for the list and the other for weather its a sample or not the third agrument shoudl be a boolian
    SD_ = variance(List, sample) ** (1/2)
    
    return SD_
print(SD(job))
def covariance(List1, List2, sample = False):
    #this funtion requieres three agruments, one for each list and one for weather its a sample, the third agrument shoudl be a boolian
    mean1 = mean(List1)
    mean2 = mean(List2)
    cov = 0
    n1 = len(List1)
    n2 = len(List2)
    if n1 == n2:
        n = n1
        for i in range(n1):
            cov += (List1[i] - mean1) * (List2[i] - mean2)
        if sample == False:
            cov = cov / n
        else:
            cov = cov / (n - 1)
        return cov
    else:
        print("List lengths are not equal")
        print("List1:", n1)
        print("List2:", n2)
    

def correlation(List1, List2):
    #this funtion bassically just uses eairlier funtions together
    cov = covariance(List1, List2)
    SD1 = SD(List1)
    SD2 = SD(List2)
    corr = cov / (SD1 * SD2)
    return corr

def skewness(List, sample = False):
    #this funtion requieres sample to be faulse in order to run, idk if this was the right call achually
    mean_ = mean(List)
    SD_ = SD(List, sample)
    skew = 0
    n = len(List)
    for val in List:
        skew += (val - mean_) ** 3
    skew = skew / (n * SD_ **3) if not sample else n * skew / ((n - 1)*(n - 2) * SD_ ** 3)
        
    return skew

def kurtosis(List, sample = False):
    #this funtion requieres sample to be faulse in order to run, idk if this was the right call achually
    mean_ = mean(List)
    mean_ = mean(List)
    kurt = 0
    SD_ = SD(List, sample)
    n = len(List)
    for val in List:
        kurt += (val - mean_) ** 4
    kurt = kurt / (n * SD_ ** 4) if sample == False else  n * (n + 1) * kurt / \
    ( (n - 1) * (n - 2) *(n - 3) * (SD_ ** 4)) - (3 *(n - 1) ** 2) / ((n - 2) * (n - 3))
    
    return kurt


#just copything this to make this homwork a little more simalir
# Out:
# 111
# 7.4
# 5
# [1]
#
# 8.708616422830897

# %%
def stats(df, sample = False):
    dct = {key:{} for key in df}
    for key, val in df.items():
        # drop any missing observations from dataframe
        val = val.dropna(axis=0)
        dct[key]["mean"] = round(mean(val),3)
        dct[key]["median"] = round(median(val),3)
        # skip mode. . .         dct[key]["mode"] = mode(val)
        dct[key]["variance"] = round(variance(val, sample),3)
        dct[key]["S.D."] = round(SD(val, sample) ,3)
        dct[key]["skewness"] = round(skewness(val, sample),3)
        dct[key]["kurtosis"] = round(kurtosis(val, sample),3)
    stats = pd.DataFrame(dct)
    return stats

# %%
#our lovly imports 
import pandas as pd
import pandas_datareader.data as web
import datetime

#picking the start date
start = datetime.datetime(2010, 1 , 1)
#picking the end date
end = datetime.datetime.today()

data_dict = {}
#picking stocks that made covid vaccines 
stocks = [ "JNJ", "MRNA", "PFE","INO"]
for key in stocks:
    data_dict[key] = web.DataReader(key, 'yahoo', start, end)

# %%
close_data = pd.concat([val["Close"] for val in data_dict.values()], keys = data_dict.keys(), axis = 1)
close_data
# Out:
#                    JNJ        MRNA        PFE   INO
# Date
# 2010-01-04   64.680000         NaN  17.960152  4.40
# 2010-01-05   63.930000         NaN  17.703985  4.68
# 2010-01-06   64.449997         NaN  17.647058  4.68
# 2010-01-07   63.990002         NaN  17.580645  4.60
# 2010-01-08   64.209999         NaN  17.722960  4.92
# ...                ...         ...        ...   ...
# 2021-12-10  165.490005  257.059998  52.779999  6.04
# 2021-12-13  168.449997  271.989990  55.200001  6.12
# 2021-12-14  170.289993  277.160004  55.540001  5.91
# 2021-12-15  171.139999  283.279999  58.799999  6.08
# 2021-12-16  173.009995  282.019989  61.250000  5.99
#
# [3011 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 32})
fig, ax = plt.subplots(figsize = (30,16))
close_data.plot.line(ax = ax, legend = True)
y_vals = ax.get_yticks()
ax.set_yticklabels([int(y) if y >= 1 else round(y,1) for y in y_vals])    
#all of them spiked when vaccines came out but Madernas spike was the most extream by far

plt.title("Stock prices of Tesla Microsft Apple and Hasbro")
plt.show()
plt.close()
# Out:
# <ipython-input-6-712a5b3e2cdf>:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([int(y) if y >= 1 else round(y,1) for y in y_vals])

# %%
import matplotlib.pyplot as plt 
plt.rcParams.update({'font.size': 28})
fig, ax = plt.subplots(figsize = (30,16))
close_data.plot.line(ax = ax, legend = True)
ax.set_yscale("log")
y_vals = ax.get_yticks()
ax.set_yticklabels([int(y) if y >= 1 else round(y,1) for y in y_vals])    

plt.title("Daily Stock Prices")
plt.show()
plt.close()
# Out:
# <ipython-input-7-681e525e1807>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([int(y) if y >= 1 else round(y,1) for y in y_vals])

# %%
price_change_data = close_data.pct_change() * 100

# %%
plt.rcParams.update({'font.size': 32,'lines.markersize':7})
fig, ax = plt.subplots(figsize = (25,16))
for key in price_change_data:
    price_change_data[key].plot.line(marker = ".", ls="", ax = ax)
plt.legend()
plt.title("Daily Price Change")
y_vals = ax.get_yticks()

ax.set_yticklabels([str(int(y))+ "%" for y in y_vals])    
#we can see as time has gone on percent change has increased, seems like the pandemic may have helped but 
#it really increased volititlity 
plt.show()
plt.close()
# Out:
# <ipython-input-40-83139e690fe1>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([str(int(y))+ "%" for y in y_vals])

# %%
stats = stats(price_change_data, sample = True)
stats
#interestingly it seems like depending on how you look at it INO or MRNA could be the most volitile
#but MRNA has done the best by far, i bet if we zoomed in on the pandemic it would be an even bigger disparity
# Out:
#              JNJ    MRNA    PFE     INO
# mean       0.038   0.491  0.050   0.149
# median     0.030   0.111  0.000   0.000
# variance   1.128  27.169  1.770  28.832
# S.D.       1.062   5.212  1.330   5.370
# skewness  -0.236   0.563  0.306   1.868
# kurtosis  10.198   3.037  6.062  21.838

# %%
fig, ax = plt.subplots(figsize = (24, 16))
price_change_data["JNJ"].hist(bins = 50, label = "JNJ")
# set horizontal axis values as percent
x_vals = ax.get_xticks()
ax.set_xticklabels([str(int(x))+ "%" for x in x_vals])    
plt.legend()
# Out:
# <ipython-input-19-64bb8687214e>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([str(int(x))+ "%" for x in x_vals])

# %%
fig, ax = plt.subplots(figsize = (24, 16))
price_change_data["MRNA"].hist(bins = 100, label = "MRNA", density = True)
# set horizontal axis values as percent
x_vals = ax.get_xticks()
ax.set_xticklabels([str(int(x))+ "%" for x in x_vals]) 
# set vertical axis values as percent
y_vals = ax.get_yticks()
ax.set_yticklabels([str(int(y * 100))+ "%" for y in y_vals]) 
#wow the lower digree of kurtosis is so odvious when it looks like this
plt.legend()
# Out:
# <ipython-input-20-b8c31d4b7dd0>:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([str(int(x))+ "%" for x in x_vals])
# <ipython-input-20-b8c31d4b7dd0>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([str(int(y * 100))+ "%" for y in y_vals])

# %%
fig, ax = plt.subplots(2,2, figsize = (24,24))
price_change_data.hist(bins = 50, alpha = .3, label = price_change_data.keys(), ax = ax, density = True)
# Out:
# array([<AxesSubplot:title={'center':'JNJ'}>,
#        <AxesSubplot:title={'center':'MRNA'}>,
#        <AxesSubplot:title={'center':'PFE'}>,
#        <AxesSubplot:title={'center':'INO'}>], dtype=object)

# %%
from pandas.plotting import table

fig, ax = plt.subplots(2,2, figsize = (24,16))
#for key in price_change_data:
price_change_data.hist(bins = 50, alpha = .3, label = price_change_data.keys(), ax = ax, density = True)

for i in range(len(ax)):
    for j in range(len(ax[i])):
        a = ax[i][j]
        stock = a.get_title()
        hist_data = stats[stock] 
        stats =table(a, hist_data, colWidths=[.1], cellColours=[[(.2,.9,.9)]]*6, loc = "center right")
        stats.scale(1.5,3)
        stats.auto_set_font_size(False)
        stats.set_fontsize(20)
        a.axvline(x = hist_data.loc["mean"], ls="--")
        x_vals = a.get_xticks()
        a.set_xticklabels([str(int(x))+ "%" for x in x_vals])   
        y_vals = a.get_yticks()
        a.set_yticklabels([str(int(y * 100))+ "%" for y in y_vals]) 

        a.grid(False)

   
plt.show()
# Out:
# <ipython-input-42-3011f0ac7e9e>:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   a.set_xticklabels([str(int(x))+ "%" for x in x_vals])
# <ipython-input-42-3011f0ac7e9e>:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   a.set_yticklabels([str(int(y * 100))+ "%" for y in y_vals])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-3011f0ac7e9e> in <module>
#       9         a = ax[i][j]
#      10         stock = a.get_title()
# ---> 11         hist_data = stats[stock]
#      12         stats =table(a, hist_data, colWidths=[.1], cellColours=[[(.2,.9,.9)]]*6, loc = "center right")
#      13         stats.scale(1.5,3)
#
# ~\anaconda3\lib\site-packages\matplotlib\table.py in __getitem__(self, position)
#     357     def __getitem__(self, position):
#     358         """Retrieve a custom cell from a given position."""
# --> 359         return self._cells[position]
#     360
#     361     @property
#
# KeyError: 'MRNA'
