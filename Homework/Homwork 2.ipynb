# %%
import pandas as pd
FTS={"Name":{"Question":"What is your name?",
            "Answer":"Finnian Speier"},
     "Major":{"Question":"What is your Major/ minor?",
             "Answer":"Economics and history"},
     "Motivation":{"Question":"What motivated you to take the class?",
                  "Answer":"Wanted to learn to apply economics in a more usful way/ started learning and really enjoyed python"},
     "Plans":{"Question":"What are your plans after graduating",
             "Answer":"Hopfully I'll get a job then go to grad school in a few years"}}
 
FTS_df=pd.DataFrame(FTS)
FTS_df
# Out:
#                         Name                       Major  \
# Question  What is your name?  What is your Major/ minor?
# Answer        Finnian Speier       Economics and history
#
#                                                  Motivation  \
# Question              What motivated you to take the class?
# Answer    Wanted to learn to apply economics in a more u...
#
#                                                       Plans
# Question               What are your plans after graduating
# Answer    Hopfully I'll get a job then go to grad school...

# %%
Admerable_economists={"James Heckman":{"Website":"https://en.wikipedia.org/wiki/James_Heckman",
                                      "Area":"Heckmen corrolation",
                                      "Bio":"Born in April 19, 1944 he won the nobel prize in ecconomics in 2000"},
                     "Daniel McFadden":{"Website":"https://en.wikipedia.org/wiki/Daniel_McFadden",
                                       "Area":"Discreat choice",
                                       "Bio":" Born July 29, 1937 he won the Nobel Prize in economics in 2000"},
                     "George Akerlof":{"Website":"https://en.wikipedia.org/wiki/George_Akerlof",
                                      "Area":"Adverse selection",
                                      "Bio":"He was bron in June 17, 1940 and won the Noebel prize in economics in 2001"},
                     "Michael Spence":{"Website":"https://en.wikipedia.org/wiki/Michael_Spence",
                                      "Area":"Signaling theory",
                                       "Bio":"He was born November 7, 1943 and won the nobel prize in 2001"},
                      "Joseph Stiglitz":{"Website":"https://en.wikipedia.org/wiki/Joseph_Stiglitz",
                                        "Area":"Screening theory",
                                        "Bio":"Born on February 9, 1943 he won the Nobel prize in economics in 2001"},
                      "Daniel Kahneman":{"Website":"https://en.wikipedia.org/wiki/Daniel_Kahneman",
                                        "Area":"Behavoral Economics",
                                        "Bio":"born on March 5, 1934 he won the nobel prize in economics in 2002"},
                      "Vernon L. Smith":{"Website":"https://en.wikipedia.org/wiki/Vernon_L._Smith",
                                        "Area":"Combinatorial auction",
                                        "Bio":"Born on January 1, 1927 he won the Nobel prize in economics in 2002"},
                      "Robert F. Engle":{"Website":"https://en.wikipedia.org/wiki/Robert_F._Engle",
                                        "Area":"ARCH",
                                        "Bio":"He was born  on November 10, 1942 and won the Nobel prize in 2003"},
                      "Clive Granger":{"Website":"https://en.wikipedia.org/wiki/Clive_Granger",
                                      "Area":"Cointetgration",
                                       "Bio":"He was born on 4 September 1934 and he won the Nobel prize in economics in 2003"},
                      "Finn E. Kydland":{"Website":"https://en.wikipedia.org/wiki/Finn_E._Kydland",
                                        "Area":"Inconcsistance in monitary polocy",
                                        "Bio":"He was born on 1 December 1943 and won the nobel prize in 2003"}}
Economists=pd.DataFrame(Admerable_economists)
print(Economists)
Economists.to_csv("Economists.csv")
# Out:
#                                              James Heckman  \
# Website        https://en.wikipedia.org/wiki/James_Heckman
# Area                                   Heckmen corrolation
# Bio      Born in April 19, 1944 he won the nobel prize ...
#
#                                            Daniel McFadden  \
# Website      https://en.wikipedia.org/wiki/Daniel_McFadden
# Area                                       Discreat choice
# Bio       Born July 29, 1937 he won the Nobel Prize in ...
#
#                                             George Akerlof  \
# Website       https://en.wikipedia.org/wiki/George_Akerlof
# Area                                     Adverse selection
# Bio      He was bron in June 17, 1940 and won the Noebe...
#
#                                             Michael Spence  \
# Website       https://en.wikipedia.org/wiki/Michael_Spence
# Area                                      Signaling theory
# Bio      He was born November 7, 1943 and won the nobel...
#
# ...
