# %%
# i didnt know exactly how to impliment these into the rough draft but these are the charts and assoseated code.

import pandas as pd
import matplotlib.pyplot as plt
import 

#for a pie chart about how many hours it takes to get a license 
df=pd.DataFrame([1.31578947,3.94736842,9.118421053,40.789,32.8947368,9.21052632] , 
    index = ["Less than 800","Between 800 and 900","Between 900 and 1000","Between 1000 and 1500","1500","Greater then 1500"]) 
df.plot(kind="pie" , subplots="True" , figsize=(6,6))    
plt.legend(loc='lower right')
plt.title("Hours to get hairdressing license")

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
#cost of a haircut relative to hours lost 
df=pd.read_excel(r"C:\Users\The Grand Tabaxi\OneDrive\Documents\Econ 411 final datasheet.xlsx")
sns.set_style('white')
sns.set_style('ticks')
sns.regplot(x="Hours",y="Cost", data=df)
# Out:
# <AxesSubplot:xlabel='Hours', ylabel='Cost'>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
#percent is percent of people who voted for joe biden 
#this is about regulatory burden in regaurds to political allinment 

df=pd.read_excel(r"C:\Users\The Grand Tabaxi\OneDrive\Documents\econ 411 log data.xlsx")
sns.set_style('white')
sns.set_style('ticks')
sns.regplot(x="Education",y="Percent", data=df)

# %%
#Greatclips Total	Greatclips to Democrats	Greatclips to Republicans	Sportsclips total	Sportclips Democrats	Sportsclips Republicans	Regis Corp total	Regis Corp Democrats	Regis Corp Republicans
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
#this is about political donations by hair chains
df=pd.read_excel(r"C:\Users\The Grand Tabaxi\OneDrive\Documents\econ 411 log data.xlsx")
df.plot(kind='area',grid='true',y=["Greatclips Total","Sportsclips total","Regis Corp total"],x="Year",title="Totle political donations by salon chains")
